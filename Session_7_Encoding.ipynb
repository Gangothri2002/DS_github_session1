# %% [markdown]
# **EDA**
#
#  **1.Data preprocess**
#
#         - missing value analysis
#
#         - data types mismatch
#
#  **2. Data analysis**
#
#         - Categorical
#
#         - Numerical
#
#         - Bi variate
#
#         - Multivariate
#
#         - Outlier analysis
#
#  **3. Feture Engineering**
#
#         - Impute the outlier
#
#         - ML needs numbers, English to numbers: Encoding
#
#         - Scaling: Standardization and Normalisation
#
#         - Transformation: Convert into Normal distribution

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **Case status**

# %%
# Step-1: find how many unique lables are there
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# Step-2: creating a dictionary
d={'Certified':0,'Denied':1}
d
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
# Step-3
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#read data again
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")
visa_df['case_status'].unique()
d={'Certified':0,'Denied':1}
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")
visa_df['continent'].unique()
d={}
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
labels=visa_df['continent'].unique()
d={}
for i in range(len(labels)):
    d[labels[i]]=i
d
# Out:
# {np.int64(1): 0,
#  np.int64(0): 1,
#  np.int64(3): 2,
#  np.int64(2): 3,
#  np.int64(5): 4,
#  np.int64(4): 5}

# %%
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")
labels=sorted(visa_df['continent'].unique())
d={labels[i]:i for i in range(len(labels))}
visa_df['continent']=visa_df['continent'].map(d)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")
for i in cat[1:]:
    labels=sorted(visa_df[i].unique())
    d={labels[i]:i for i in range(len(labels))}
    visa_df[i]=visa_df[i].map(d)

visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# - sklean aka scikit-learn
#
#     - preprocessing
#
#        - labelEncoder
#
# - **Step-1:** Import the module
#
# - **step-2:** Save the module
#
# - **step-3:** Apply filt_transform
#
#        - fitting means creating a dictionary
#
#        - transfor means apply dictionary so that data will be transformed

# %%
#Read data again
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
le.inverse_transform(visa_df['continent'])[:5]
# Out:
# array(['Asia', 'Asia', 'Asia', 'Asia', 'Africa'], dtype=object)

# %%
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **OneHotEncoder**
#
# - OneHot means at a time one will be ON(1) another will be OFF(0)
#
# |case_staus|case_status_Denied|case_staus_Certified
# |-|-|-|
# |Denied|1|0
# |certified|0|1
# |certified|0|1
# |Denied|1|0

# %%
visa_df=pd.read_csv(r"C:\Users\kkali\Documents\NOTES\Visadataset.csv")

# %%
pd.get_dummies(visa_df,columns=cat[1:],dtype=int)
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...

# %% [markdown]
# **LabelEncoder vs OneHotEncoder**
#
# - Generally we dont want a relationship between input columns
#
# - we need both input columns are **not correlated** each other
#
# - we need both input columns are **independent(x,y)** each other
#
# - we need both input columns are **Perdencicular** each other
#
# - we need both input columns are **Orthogonal** each other
#
# - we need both input columns are **90 degrees phase shift** each other
#
# - OneHotEncoder will achieve all the above
#
# - But OneHotEncoder creates new columns
#
#    - Columns are increase means dimenssions are increase
#
#    - More dimension data need more processing time
#
#    - More dimension data need more infra(like tpu)
#
#    - This is called **Curse of Dimensionality**
